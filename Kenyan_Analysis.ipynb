# %%
#important pandas library as pd
import pandas as pd

# %%
#Load our csv file
filepath ="DataFiles/violence_data.csv"
df=pd.read_csv(filepath)

# %%
#Display the first 5 rows of our data set
df.head()
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8

# %%
#Checking the number of rows and columns in our dataset
df.shape
# Out:
# (12600, 8)

# %%
#Checking the columns we have to determine which ones to keep and which ones to remove
df.columns
# Out:
# Index(['RecordID', 'Country', 'Gender', 'Demographics Question',
#        'Demographics Response', 'Question', 'Survey Year', 'Value'],
#       dtype='object')

# %%
#Dropping the column named Value
df=df.drop("Value", axis=1)

# %%
df
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# ...

# %%
#Acess the Survey year column
df["Survey Year"]
# Out:
# 0        01/01/2015
# 1        01/01/2015
# 2        01/01/2015
# 3        01/01/2015
# 4        01/01/2015
#             ...
# 12595    01/01/2015
# 12596    01/01/2015
# 12597    01/01/2015
# 12598    01/01/2015
# 12599    01/01/2015
# Name: Survey Year, Length: 12600, dtype: object

# %%
#Drop the Survey Year column
df=df.drop("Survey Year" ,axis=1)

# %%
df
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# ...

# %%
#Filtered Kenya data
df_filtered = df[df["Country"] == "Kenya"]

# %%
df_filtered
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 6120       385   Kenya      F                   Age                 15-24
# 6121       385   Kenya      F                   Age                 25-34
# 6122       385   Kenya      F                   Age                 35-49
# 6123       105   Kenya      F                   Age                 15-24
# 6124       105   Kenya      F                   Age                 25-34
# ...        ...     ...    ...                   ...                   ...
# 6295       175   Kenya      M             Residence                 Urban
# 6296       245   Kenya      M             Residence                 Rural
# 6297       245   Kenya      M             Residence                 Urban
# 6298       315   Kenya      M             Residence                 Rural
# 6299       315   Kenya      M             Residence                 Urban
#
#                                      Question
# ...

# %%
df_filtered_females = df_filtered[df_filtered["Gender"] =="F"]
df_filtered_females
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 6120       385   Kenya      F                   Age                 15-24
# 6121       385   Kenya      F                   Age                 25-34
# 6122       385   Kenya      F                   Age                 35-49
# 6123       105   Kenya      F                   Age                 15-24
# 6124       105   Kenya      F                   Age                 25-34
# ...        ...     ...    ...                   ...                   ...
# 6205       175   Kenya      F             Residence                 Urban
# 6206       245   Kenya      F             Residence                 Rural
# 6207       245   Kenya      F             Residence                 Urban
# 6208       315   Kenya      F             Residence                 Rural
# 6209       315   Kenya      F             Residence                 Urban
#
#                                      Question
# ...

# %%
df_filtered_females
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 6120       385   Kenya      F                   Age                 15-24
# 6121       385   Kenya      F                   Age                 25-34
# 6122       385   Kenya      F                   Age                 35-49
# 6123       105   Kenya      F                   Age                 15-24
# 6124       105   Kenya      F                   Age                 25-34
# ...        ...     ...    ...                   ...                   ...
# 6205       175   Kenya      F             Residence                 Urban
# 6206       245   Kenya      F             Residence                 Rural
# 6207       245   Kenya      F             Residence                 Urban
# 6208       315   Kenya      F             Residence                 Rural
# 6209       315   Kenya      F             Residence                 Urban
#
#                                      Question
# ...

# %%
df_filtered_females[df_filtered_females["Demographics Question"]=="Age"]
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 6120       385   Kenya      F                   Age                 15-24
# 6121       385   Kenya      F                   Age                 25-34
# 6122       385   Kenya      F                   Age                 35-49
# 6123       105   Kenya      F                   Age                 15-24
# 6124       105   Kenya      F                   Age                 25-34
# 6125       105   Kenya      F                   Age                 35-49
# 6126        35   Kenya      F                   Age                 15-24
# 6127        35   Kenya      F                   Age                 25-34
# 6128        35   Kenya      F                   Age                 35-49
# 6129       175   Kenya      F                   Age                 15-24
# 6130       175   Kenya      F                   Age                 25-34
# 6131       175   Kenya      F                   Age                 35-49
# ...

# %%
#checking for null values
df.isnull().any().sum()
# Out:
# 0

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df["Demographics Response"]
# Out:
# 0                       Never married
# 1                              Higher
# 2                           Secondary
# 3                             Primary
# 4        Widowed, divorced, separated
#                      ...
# 12595                           Urban
# 12596                           Rural
# 12597                           Urban
# 12598                           Rural
# 12599                           Urban
# Name: Demographics Response, Length: 12600, dtype: object

# %%
Never_Married_Females = df_filtered_females[df_filtered_females["Demographics Response"] == "Never married"]

# %%
Never_Married_Females
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 6181       385   Kenya      F        Marital status         Never married
# 6184       105   Kenya      F        Marital status         Never married
# 6187        35   Kenya      F        Marital status         Never married
# 6190       175   Kenya      F        Marital status         Never married
# 6193       245   Kenya      F        Marital status         Never married
# 6196       315   Kenya      F        Marital status         Never married
#
#                                      Question
# 6181     ... for at least one specific reason
# 6184               ... if she argues with him
# 6187                ... if she burns the food
# 6190  ... if she goes out without telling him
# 6193         ... if she neglects the children
# 6196  ... if she refuses to have sex with him

# %%
Never_Married_total = df[df["Demographics Response"] == "Never married"]

Never_Married_total
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 15            1  Afghanistan      M        Marital status
# 81          351  Afghanistan      F        Marital status
# 84           71  Afghanistan      F        Marital status
# 87          141  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12574       140     Zimbabwe      M        Marital status
# 12577        70     Zimbabwe      M        Marital status
# 12580       210     Zimbabwe      M        Marital status
# 12583       280     Zimbabwe      M        Marital status
# 12586       350     Zimbabwe      M        Marital status
#
#       Demographics Response                                 Question
# 0             Never married                ... if she burns the food
# 15            Never married                ... if she burns the food
# ...

# %%
df["Never_Married_Females"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Never_Married_Females'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df["Never_Married_Females"].sum()
#
# ...

# %%
df['Never_Married_total'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Never_Married_total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df['Never_Married_total'].sum()
#
# ...

# %%
df.columns
# Out:
# Index(['RecordID', 'Country', 'Gender', 'Demographics Question',
#        'Demographics Response', 'Question'],
#       dtype='object')
